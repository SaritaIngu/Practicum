# %%
import numpy as np
import pandas as pd

import pytwits
import requests

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer as sentintentanalyzer

# %%
tweets = []
ticker_list = ["TSLA", "GOOG", "AAPL", "AMZN", "FB", "MSFT"]
access_token = '26c8e5b3d7bd2903f6091364ae85a91cce9b9aa4'
stocktwits = pytwits.StockTwits(access_token=access_token) # This would also work without passing token.
#for ticker in ticker_list:
symbol, cursor, messages = stocktwits.streams(path = 'symbol', id = "AAPL", limit = 30) # max limit on messages = 60)

for msg in messages:
    tweets.append(msg.body)

# %%
print(tweets)
# Out:
# ['What&#39;s Funny is how quickly the Trade News Flow will change once Corporate Buybacks Stop after Labor Day $DIA $DJIA $AAPL $SPY $MSFT $V -BUY', '@Craycray1000 - Funny... \n-- You start @ IPO... (Pre-Canada Legal?) \n--+ Better off going $AAPL  xD \n \n+++ Now? #RideAlong #420', '$AAPL analysts on Estimize are expecting 15.40% YoY revenue growth for Q4, down from 17.30% in Q3 [Reporting 10/30 AMC]\nhttp://www.estimize.com/intro/aapl?chart=historical&amp;metric_name=revenue&amp;utm_content=AAPL&amp;utm_medium=revenue_growth&amp;utm_source=stocktwits', 'Hot Options Report For End Of Day August 27th – $AAL, $AMD, $BAC, $AAPL \nhttp://www.theoptionsinsider.com/hot-options-report-for-end-of-day-august-27th-aal-amd-bac-aapl/', '$AAPL Venture capitalist Gene Munster advocated for a marriage of the two companies in a blog post. https://stocknews.com/news/aapl-analyst-apple-inc-aapl-should-take-a-long-hard-look/', '$AAPL PUSHES THROUGH PRIOR SESSION HIGH: https://techniquant.com/reports/stock-aapl-daily-technical-analysis-report-for-2018-08-27/', '$AAPL thank the artman1033 for the graphic, as always:', '$AAPL Apple may approach $6B wearables rev for the holiday quarter, FY Q1 2019. And they&#39;ve only just begun.', '$aapl EXP:8/31/2018|MaxPain:215.0|HighPutOI:212.5(11671)|HighCallOI:220.0(18748) http://www.opricot.com/ticker/aapl/optiongraphs', '$AMZN $SQ $GOOG $AAPL looking to acquire an undervalued electronic health records IT company innovating in AI and blockchain? $MTBC ready!', '$AAPL thank you apple !!!', 'Okay good day. $AAPL $NVDA $CRM $SQ Watch for a 300-400 pt rally tomorrow.', '@mrspicak I still have plenty in $AAPL! 💰🚀', '$AAPL WS just keeps on delivering dips...AWESOME! $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$', '$NEPT $AAPL $TLRY $acb.ca $cron $deo $STZ  \nNEPT deal will explode soon.', 'oh looks like one or 2 people want to get out of tech at the close. Algos will take there shares and move us up. #300pts2mrw $AAPL $NVDA', 'Looks like The Bank of $AAPL won&#39;t see $220 until tomorrow. But $225 is still in play for Friday. China good news tomorrow. #MAGA', '$HMNY HEY $AAPL BUY MP!!! JUST DA BRAND ALONG HAS SOME VALUE, TAKE THIS OUTTA THE HANDS OF TED... ANYBODY WILL DO BETTER THAN HIM!! PLZ!!!', 'Who said $comp underperforms in Aug. $AAPL $NVDA $AMD $TSLA', '$AAPL Sold a tiny bit @ $218.16. (Shopping sports cars soon.) Still bullish EOY. Money doesn&#39;t buy happiness, but it&#39;s part of the recipe!', 'Bullish Swing Trade Setups To Attack This Week $AAPL $AMZN $BA $C $BAC $FDX $NFLX $LULU + More \nhttps://www.shareplanner.com/featured-blogs/ryan-mallory/trade-setups/24771-bullish-swing-trade-setups-to-attack-this-week.html', 'Tesla Zaps Go-Private Plans; Wall Street Reacts https://benzinga.com/z/12264796 $AAPL $TSLA', '@ASM $AAPL is valued correctly $AMZN is way overvalued. but they, millenials who can&#39;t tie their shoes buy it because it&#39;s trendy lol', 'ALL TIME CLOSING HIGH FOR $AMZN - 2 POINTS AWAY FROM INTRADAY HIGH - BIG BREAKOUT COMING TOMORROW IMO $SPY $QQQ $AAPL $FB $GOOGL', 'The Bank of $AAPL returning to the +1% daily mark. :)', '$SPY $QQQ $IWM $AAPL $AMZN $NVDA $NFLX $CGC  Let&#39;s go, pump it higher, want to see a ramp it into the close...', '$NFLX $12 dollar dump.. 1st set wave at #FaangReef. some want their money back..   $GOOG $AAPL $FB #AMZN $SPY', '$AAPL just look at it', '$AAPL $TSLA he’s as wrong on this as he was wrong on his years-long prediction of an Apple television', '$AAPL Apple Wearables rev *estimated* -look at Q3 17 vs Q3 18. Just look at it.']

# %%
tweet_df = pd.DataFrame(tweets)
tweet_df[0] = tweet_df[0].str.replace("&#39;","'")
tweet_df.columns = ['Tweet']

# %%
def sentiment(tweet):
    analyze = sentintentanalyzer()
    comp = analyze.polarity_scores(tweet)['compound']
    if comp > 0:
        return "Positive"
    elif comp < 0:
        return "Negative"
    else:
        return "Neutral"

def polarity(tweet):
    analyze = sentintentanalyzer()
    return analyze.polarity_scores(tweet)['compound']

# %%
tweet_df['Sentiment'] = tweet_df['Tweet'].apply(lambda x: sentiment(x))
tweet_df['Score'] = tweet_df['Tweet'].apply(lambda x: polarity(x))

# %%
tweet_df
# Out:
#                                                 Tweet Sentiment   Score
# 0   What's Funny is how quickly the Trade News Flo...  Positive  0.1779
# 1   @Craycray1000 - Funny... \n-- You start @ IPO....  Positive  0.7941
# 2   $AAPL analysts on Estimize are expecting 15.40...  Positive  0.3818
# 3   Hot Options Report For End Of Day August 27th ...   Neutral  0.0000
# 4   $AAPL Venture capitalist Gene Munster advocate...   Neutral  0.0000
# 5   $AAPL PUSHES THROUGH PRIOR SESSION HIGH: https...   Neutral  0.0000
# 6   $AAPL thank the artman1033 for the graphic, as...  Positive  0.3612
# 7   $AAPL Apple may approach $6B wearables rev for...  Positive  0.4019
# 8   $aapl EXP:8/31/2018|MaxPain:215.0|HighPutOI:21...   Neutral  0.0000
# 9   $AMZN $SQ $GOOG $AAPL looking to acquire an un...  Positive  0.4199
# 10                          $AAPL thank you apple !!!  Positive  0.5229
# 11  Okay good day. $AAPL $NVDA $CRM $SQ Watch for ...  Positive  0.5859
# 12         @mrspicak I still have plenty in $AAPL! 💰🚀   Neutral  0.0000
# 13  $AAPL WS just keeps on delivering dips...AWESO...   Neutral  0.0000
# 14  $NEPT $AAPL $TLRY $acb.ca $cron $deo $STZ  \nN...   Neutral  0.0000
# 15  oh looks like one or 2 people want to get out ...  Positive  0.6124
# 16  Looks like The Bank of $AAPL won't see $220 un...  Positive  0.8271
# 17  $HMNY HEY $AAPL BUY MP!!! JUST DA BRAND ALONG ...  Positive  0.7762
# 18  Who said $comp underperforms in Aug. $AAPL $NV...   Neutral  0.0000
# 19  $AAPL Sold a tiny bit @ $218.16. (Shopping spo...  Negative -0.3080
# 20  Bullish Swing Trade Setups To Attack This Week...  Negative -0.4767
# 21  Tesla Zaps Go-Private Plans; Wall Street React...   Neutral  0.0000
# 22  @ASM $AAPL is valued correctly $AMZN is way ov...  Positive  0.6858
# 23  ALL TIME CLOSING HIGH FOR $AMZN - 2 POINTS AWA...   Neutral  0.0000
# 24  The Bank of $AAPL returning to the +1% daily m...  Positive  0.4588
# 25  $SPY $QQQ $IWM $AAPL $AMZN $NVDA $NFLX $CGC  L...  Positive  0.0772
# 26  $NFLX $12 dollar dump.. 1st set wave at #Faang...  Positive  0.0772
# 27                              $AAPL just look at it   Neutral  0.0000
# 28  $AAPL $TSLA he’s as wrong on this as he was wr...  Negative -0.7351
# 29  $AAPL Apple Wearables rev *estimated* -look at...   Neutral  0.0000

# %%
twit_df = pd.DataFrame(tweets)
twit_df[0] = twit_df[0].str.replace("&#39;","'")
twit_df[0] = twit_df[0].str.replace("$","")
twit_df.columns = ['Tweet']
twit_df['Sentiment'] = twit_df['Tweet'].apply(lambda x: sentiment(x))
twit_df['Score'] = twit_df['Tweet'].apply(lambda x: polarity(x))
twit_df
# Out:
#                                                 Tweet Sentiment   Score
# 0   What's Funny is how quickly the Trade News Flo...  Positive  0.1779
# 1   @Craycray1000 - Funny... \n-- You start @ IPO....  Positive  0.7941
# 2   AAPL analysts on Estimize are expecting 15.40%...  Positive  0.3818
# 3   Hot Options Report For End Of Day August 27th ...   Neutral  0.0000
# 4   AAPL Venture capitalist Gene Munster advocated...   Neutral  0.0000
# 5   AAPL PUSHES THROUGH PRIOR SESSION HIGH: https:...   Neutral  0.0000
# 6   AAPL thank the artman1033 for the graphic, as ...  Positive  0.3612
# 7   AAPL Apple may approach 6B wearables rev for t...  Positive  0.4019
# 8   aapl EXP:8/31/2018|MaxPain:215.0|HighPutOI:212...   Neutral  0.0000
# 9   AMZN SQ GOOG AAPL looking to acquire an underv...  Positive  0.4199
# 10                           AAPL thank you apple !!!  Positive  0.5229
# 11  Okay good day. AAPL NVDA CRM SQ Watch for a 30...  Positive  0.5859
# 12          @mrspicak I still have plenty in AAPL! 💰🚀   Neutral  0.0000
# 13  AAPL WS just keeps on delivering dips...AWESOME!    Neutral  0.0000
# 14  NEPT AAPL TLRY acb.ca cron deo STZ  \nNEPT dea...   Neutral  0.0000
# 15  oh looks like one or 2 people want to get out ...  Positive  0.6124
# 16  Looks like The Bank of AAPL won't see 220 unti...  Positive  0.8271
# 17  HMNY HEY AAPL BUY MP!!! JUST DA BRAND ALONG HA...  Positive  0.7762
# 18  Who said comp underperforms in Aug. AAPL NVDA ...   Neutral  0.0000
# 19  AAPL Sold a tiny bit @ 218.16. (Shopping sport...  Negative -0.3080
# 20  Bullish Swing Trade Setups To Attack This Week...  Negative -0.4767
# 21  Tesla Zaps Go-Private Plans; Wall Street React...   Neutral  0.0000
# 22  @ASM AAPL is valued correctly AMZN is way over...  Positive  0.6858
# 23  ALL TIME CLOSING HIGH FOR AMZN - 2 POINTS AWAY...   Neutral  0.0000
# 24  The Bank of AAPL returning to the +1% daily ma...  Positive  0.4588
# 25  SPY QQQ IWM AAPL AMZN NVDA NFLX CGC  Let's go,...  Positive  0.0772
# 26  NFLX 12 dollar dump.. 1st set wave at #FaangRe...  Positive  0.0772
# 27                               AAPL just look at it   Neutral  0.0000
# 28  AAPL TSLA he’s as wrong on this as he was wron...  Negative -0.7351
# 29  AAPL Apple Wearables rev *estimated* -look at ...   Neutral  0.0000
