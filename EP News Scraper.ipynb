# %%
import bs4 as bs
import csv
import requests
import urllib
from urllib.request import urlopen

# Seeking Alpha News Parser

stocks = ["TSLA", "GOOG", "AAPL", "AMZN", "FB", "MSFT"]
AllArticles=[]
for stock in stocks :  
 url = "https://seekingalpha.com/symbol/"+stock+"?s="+stock
 #print(url)
    
 req = urllib.request.Request(url, headers={'User-Agent' : "foobar"})
 sourcehtml = urlopen(req)
 soup = bs.BeautifulSoup(sourcehtml,"lxml")

#Parse the document using soup object and extract the required text 
 analysisDiv = soup.find("div", {"class": "feed analysis"})
 NewsDiv = soup.find("div", {"class": "feed news"})
 myNewsContentdivs = NewsDiv.findAll("div", {"class": "content"})
 myAnalysisContentdivs = analysisDiv.findAll("div", {"class": "content"})
    
 Top5 = 0
 Top2 = 0
 print("-----------"+stock+"------------")
 for Contentdiv in myNewsContentdivs:
        
      if(Top5 >= 5):
        break;
        
      #Date Div
      Datediv = Contentdiv.find("div", {"class": "date_on_by"})
      DateText = Datediv.get_text()
      strs = DateText.split("•")
      SaveDate = "Today"
    
      #If I do not have Date information, not considering the article for now.
      if(len(strs)>=2):       
       SaveDate = strs[1]
       if SaveDate.find(",") == -1:            
          SaveDate = strs[2]       
      else:
        break;
        
      SaveDateFormatted  = ConvertDate(SaveDate)
     
      
      #Article Div        
      Articlediv = Contentdiv.find("div", {"class": "symbol_article"})
       #Extract Article
      atextHolder = Articlediv.findAll('a')
      articleHolder = atextHolder[0].get_text().strip()
      articlehref = atextHolder[0]['href']      
      print(SaveDate +" -  "+articleHolder) 
      articleLink = articlehref
      if articlehref.find(".com") != -1:            
          print(articlehref)
      else:
          articleLink = 'https://seekingalpha.com'+articlehref
          print('https://seekingalpha.com'+articlehref)
    
      print("\n")
      lstarticle = [stock, SaveDateFormatted, articleHolder, articleLink]
      AllArticles.append(lstarticle)
      Top5 = Top5 + 1
    
    
 for Contentdiv in myAnalysisContentdivs:
        
      if(Top2 >= 2):
        break;
        
      #Date Div
      Datediv = Contentdiv.find("div", {"class": "date_on_by"})
      DateText = Datediv.get_text()
      strs = DateText.split("•")
      SaveDate = "Today"
    
      #If I do not have Date information, not considering the article for now.
      if(len(strs)>=2):       
       SaveDate = strs[1]
       if SaveDate.find(",") == -1:            
          SaveDate = strs[2]       
      else:
        break;
      SaveDateFormatted  = ConvertDate(SaveDate)
      
      #Article Div        
      Articlediv = Contentdiv.find("div", {"class": "symbol_article"})
       #Extract Article
      atextHolder = Articlediv.findAll('a')
      articleHolder = atextHolder[0].get_text().strip()
      articlehref = atextHolder[0]['href']      
      print(SaveDate +" -  "+articleHolder) 
      articleLink = articlehref
      if articlehref.find(".com") != -1:            
          print(articlehref)
      else:
          articleLink = 'https://seekingalpha.com'+articlehref
          print('https://seekingalpha.com'+articlehref)
    
      print("\n")
      lstarticle = [stock, SaveDateFormatted, articleHolder, articleLink]
      AllArticles.append(lstarticle)
      Top2 = Top2 + 1
       
AllArticles
# Out:
# -----------TSLA------------
# 3
# 2018-07-25 15:42:00
# Today, 3:42 PM -  Bipartisan Senate bills aims to delay auto tariffs
# https://seekingalpha.com/news/3373587-bipartisan-senate-bills-aims-delay-auto-tariffs
#
#
# 1
# 2018-07-25 13:27:00
# Today, 1:27 PM -  When Elon Musk comes calling
# https://seekingalpha.com/news/3373545-elon-musk-comes-calling
#
#
# 10
# 2018-07-25 10:34:00
# Today, 10:34 AM -  Nomura talks up Tesla
# https://seekingalpha.com/news/3373483-nomura-talks-tesla
#
#
# Yesterday, 12:34 PM -  Bull market in Tesla CDS
# https://seekingalpha.com/news/3372931-bull-market-tesla-cds
#
#
# Yesterday, 8:34 AM -  Morgan Stanley sees 'fair value' on Tesla
# https://seekingalpha.com/news/3372789-morgan-stanley-sees-fair-value-tesla
#
#
# 5
# 2018-07-25 17:52:00
# Today, 5:52 PM -  Tesla And 'Supplier Discountgate'
# https://seekingalpha.com/article/4190146-tesla-supplier-discountgate
#
#
# 1
# 2018-07-25 13:26:00
# Today, 1:26 PM -  Tesla And Montana Skeptic: Our Response
# https://seekingalpha.com/article/4189933-tesla-montana-skeptic-response
#
#
# -----------GOOG------------
# 2
# 2018-07-25 14:27:00
# Today, 2:27 PM -  Google Drive approaches 1B users
# https://seekingalpha.com/news/3373568-google-drive-approaches-1b-users
#
#
# 1
# 2018-07-25 13:16:00
# Today, 1:16 PM -  Google announces Edge TPU, Cloud IoT Edge
# https://seekingalpha.com/news/3373552-google-announces-edge-tpu-cloud-iot-edge
#
#
# 8
# 2018-07-25 08:36:00
# Today, 8:36 AM -  Waymo cars will drive customers to Walmart
# https://seekingalpha.com/news/3373397-waymo-cars-will-drive-customers-walmart
#
#
# Yesterday, 3:33 PM -  Google announces the Cloud Services Platform
# https://seekingalpha.com/news/3372990-google-announces-cloud-services-platform
#
#
# Yesterday, 9:18 AM -  Analysts raise Alphabet targets after earnings
# https://seekingalpha.com/news/3372821-analysts-raise-alphabet-targets-earnings
#
#
# 6
# 2018-07-25 06:53:00
# Today, 6:53 AM -  Andvari Associates Q2 2018 Letter
# https://seekingalpha.com/article/4189782-andvari-associates-q2-2018-letter
#
#
# 5
# 2018-07-25 05:14:00
# Today, 5:14 AM -  Alphabet: Consistent Performance, Reasonable Expectations
# https://seekingalpha.com/article/4189763-alphabet-consistent-performance-reasonable-expectations
#
#
# -----------AAPL------------
# 11
# 2018-07-25 11:57:00
# Today, 11:57 AM -  Morgan Stanley: Fall iPhone facing production delay
# https://seekingalpha.com/news/3373520-morgan-stanley-fall-iphone-facing-production-delay
#
#
# Yesterday, 1:36 PM -  Apple confirms bug causing MacBook Pro performance issues
# https://seekingalpha.com/news/3372953-apple-confirms-bug-causing-macbook-pro-performance-issues
#
#
# Yesterday, 10:35 AM -  Apple faces two hits from Trump's tariff threat
# https://seekingalpha.com/news/3372864-apple-faces-two-hits-trumps-tariff-threat
#
#
# Fri, Jul. 20 -  Apple gets deadline to comply with Indian telecom regulation
# https://seekingalpha.com/news/3372146-apple-gets-deadline-comply-indian-telecom-regulation
#
#
# Fri, Jul. 20 -  Apple Watch, Fitbit, and Sonos in the Chinese tariff talks
# https://seekingalpha.com/news/3372067-apple-watch-fitbit-sonos-chinese-tariff-talks
#
#
# 11
# 2018-07-25 11:28:00
# Today, 11:28 AM -  Apple: The Only Number That Matters
# https://seekingalpha.com/article/4189875-apple-number-matters
#
#
# Thu, Jul. 19 -  Apple: Omnipotent And Undervalued
# https://seekingalpha.com/article/4188391-apple-omnipotent-undervalued
#
#
# -----------AMZN------------
# 3
# 2018-07-25 03:28:00
# Today, 3:28 AM -  Head of Amazon Studios to depart
# https://seekingalpha.com/news/3373203-head-amazon-studios-depart
#
#
# Mon, Jul. 23 -  Amazon accelerator announces new startups
# https://seekingalpha.com/news/3372451-amazon-accelerator-announces-new-startups
#
#
# Mon, Jul. 23 -  Amazon -1.5% as President Trump tweets about Post Office, Washington Post
# https://seekingalpha.com/news/3372371-amazon-minus-1_5-percent-president-trump-tweets-post-office-washington-post
#
#
# Sat, Jul. 21 -  Amazon, Toyota, Alcoa attempt to counter tariffs
# https://seekingalpha.com/news/3372197-amazon-toyota-alcoa-attempt-counter-tariffs
#
#
# Fri, Jul. 20 -  Deutsche Bank: Amazon top internet pick with 21% upside
# https://seekingalpha.com/news/3371997-deutsche-bank-amazon-top-internet-pick-21-percent-upside
#
#
# 11
# 2018-07-25 11:13:00
# Today, 11:13 AM -  TGV Partners Fund Shareholder Letter H1 2018
# https://seekingalpha.com/article/4189881-tgv-partners-fund-shareholder-letter-h1-2018
#
#
# 10
# 2018-07-25 10:00:00
# Today, 10:00 AM -  How To Make Sense Of Amazon's Mad Valuation
# https://seekingalpha.com/article/4189659-make-sense-amazons-mad-valuation
#
#
# -----------FB------------
# 5
# 2018-07-25 17:40:00
# Today, 5:40 PM -  Facebook -20% on guidance for slowing revenue growth
# https://seekingalpha.com/news/3373825-facebook-minus-20-percent-guidance-slowing-revenue-growth
#
#
# 5
# 2018-07-25 17:06:00
# Today, 5:06 PM -  Twitter, Snap dip amid Facebook earnings slide
# https://seekingalpha.com/news/3373782-twitter-snap-dip-amid-facebook-earnings-slide
#
#
# 4
# 2018-07-25 16:13:00
# Today, 4:13 PM -  Facebook -8.3% as revenues trail expectations
# https://seekingalpha.com/news/3373630-facebook-minus-8_3-percent-revenues-trail-expectations
#
#
# 4
# 2018-07-25 16:07:00
# Today, 4:07 PM -  Facebook beats by $0.03, misses on revenue
# https://seekingalpha.com/news/3373612-facebook-beats-0_03-misses-revenue
#
#
# 10
# 2018-07-25 10:17:00
# Today, 10:17 AM -  NYT: China withdraws approval for Facebook unit
# https://seekingalpha.com/news/3373474-nyt-china-withdraws-approval-facebook-unit
#
#
# 10
# 2018-07-25 10:59:00
# Today, 10:59 AM -  RV Capital Co Investor Letter H1 2018
# https://seekingalpha.com/article/4189877-rv-capital-co-investor-letter-h1-2018
#
#
# Yesterday, 8:10 PM -  Facebook Q2: Instagram Vs. #DeleteFacebook
# https://seekingalpha.com/article/4189683-facebook-q2-instagram-vs-deletefacebook
#
#
# -----------MSFT------------
# Fri, Jul. 20 -  Piper Jaffray raises its Microsoft target to near $1T market cap
# https://seekingalpha.com/news/3372136-piper-jaffray-raises-microsoft-target-near-1t-market-cap
#
#
# Fri, Jul. 20 -  Microsoft hits all-time high after earnings strength
# https://seekingalpha.com/news/3372088-microsoft-hits-time-high-earnings-strength
#
#
# Fri, Jul. 20 -  Analysts boost Microsoft targets after strong earnings
# https://seekingalpha.com/news/3372006-analysts-boost-microsoft-targets-strong-earnings
#
#
# Fri, Jul. 20 -  Microsoft +3.7% after upside Q1 guidance
# https://seekingalpha.com/news/3371935-microsoft-plus-3_7-percent-upside-q1-guidance
#
#
# Thu, Jul. 19 -  Microsoft Corporation (MSFT) CEO Satya Nadella on Q4 2018 Results - Earnings Call Transcript
# https://seekingalpha.com/article/4188569-microsoft-corporation-msft-ceo-satya-nadella-q4-2018-results-earnings-call-transcript
#
#
# 11
# 2018-07-25 11:13:00
# Today, 11:13 AM -  TGV Partners Fund Shareholder Letter H1 2018
# https://seekingalpha.com/article/4189881-tgv-partners-fund-shareholder-letter-h1-2018
#
#
# Yesterday, 2:45 PM -  Microsoft Overvaluation Concerns: DéJà Vu All Over Again
# https://seekingalpha.com/article/4189584-microsoft-overvaluation-concerns-deja-vu
# [['TSLA',
#   '07/25/2018  15:42',
#   'Bipartisan Senate bills aims to delay auto tariffs',
#   'https://seekingalpha.com/news/3373587-bipartisan-senate-bills-aims-delay-auto-tariffs'],
#  ['TSLA',
#   '07/25/2018  13:27',
#   'When Elon Musk comes calling',
#   'https://seekingalpha.com/news/3373545-elon-musk-comes-calling'],
#  ['TSLA',
#   '07/25/2018  10:34',
#   'Nomura talks up Tesla',
#   'https://seekingalpha.com/news/3373483-nomura-talks-tesla'],
#  ['TSLA',
#   '07/24/2018 12:34',
#   'Bull market in Tesla CDS',
#   'https://seekingalpha.com/news/3372931-bull-market-tesla-cds'],
#  ['TSLA',
#   '07/24/2018 08:34',
#   "Morgan Stanley sees 'fair value' on Tesla",
#   'https://seekingalpha.com/news/3372789-morgan-stanley-sees-fair-value-tesla'],
#  ['TSLA',
#   '07/25/2018  17:52',
#   "Tesla And 'Supplier Discountgate'",
#   'https://seekingalpha.com/article/4190146-tesla-supplier-discountgate'],
#  ['TSLA',
#   '07/25/2018  13:26',
#   'Tesla And Montana Skeptic: Our Response',
#   'https://seekingalpha.com/article/4189933-tesla-montana-skeptic-response'],
#  ['GOOG',
#   '07/25/2018  14:27',
#   'Google Drive approaches 1B users',
#   'https://seekingalpha.com/news/3373568-google-drive-approaches-1b-users'],
#  ['GOOG',
#   '07/25/2018  13:16',
#   'Google announces Edge TPU, Cloud IoT Edge',
#   'https://seekingalpha.com/news/3373552-google-announces-edge-tpu-cloud-iot-edge'],
#  ['GOOG',
#   '07/25/2018  08:36',
#   'Waymo cars will drive customers to Walmart',
#   'https://seekingalpha.com/news/3373397-waymo-cars-will-drive-customers-walmart'],
#  ['GOOG',
#   '07/24/2018 15:33',
#   'Google announces the Cloud Services Platform',
#   'https://seekingalpha.com/news/3372990-google-announces-cloud-services-platform'],
#  ['GOOG',
#   '07/24/2018 09:18',
#   'Analysts raise Alphabet targets after earnings',
#   'https://seekingalpha.com/news/3372821-analysts-raise-alphabet-targets-earnings'],
#  ['GOOG',
#   '07/25/2018  06:53',
#   'Andvari Associates Q2 2018 Letter',
#   'https://seekingalpha.com/article/4189782-andvari-associates-q2-2018-letter'],
#  ['GOOG',
#   '07/25/2018  05:14',
#   'Alphabet: Consistent Performance, Reasonable Expectations',
#   'https://seekingalpha.com/article/4189763-alphabet-consistent-performance-reasonable-expectations'],
#  ['AAPL',
#   '07/25/2018  11:57',
#   'Morgan Stanley: Fall iPhone facing production delay',
#   'https://seekingalpha.com/news/3373520-morgan-stanley-fall-iphone-facing-production-delay'],
#  ['AAPL',
#   '07/24/2018 13:36',
#   'Apple confirms bug causing MacBook Pro performance issues',
#   'https://seekingalpha.com/news/3372953-apple-confirms-bug-causing-macbook-pro-performance-issues'],
#  ['AAPL',
#   '07/24/2018 10:35',
#   "Apple faces two hits from Trump's tariff threat",
#   'https://seekingalpha.com/news/3372864-apple-faces-two-hits-trumps-tariff-threat'],
#  ['AAPL',
#   '07/20/2018',
#   'Apple gets deadline to comply with Indian telecom regulation',
#   'https://seekingalpha.com/news/3372146-apple-gets-deadline-comply-indian-telecom-regulation'],
#  ['AAPL',
#   '07/20/2018',
#   'Apple Watch, Fitbit, and Sonos in the Chinese tariff talks',
#   'https://seekingalpha.com/news/3372067-apple-watch-fitbit-sonos-chinese-tariff-talks'],
#  ['AAPL',
#   '07/25/2018  11:28',
#   'Apple: The Only Number That Matters',
#   'https://seekingalpha.com/article/4189875-apple-number-matters'],
#  ['AAPL',
#   '07/19/2018',
#   'Apple: Omnipotent And Undervalued',
#   'https://seekingalpha.com/article/4188391-apple-omnipotent-undervalued'],
#  ['AMZN',
#   '07/25/2018  03:28',
#   'Head of Amazon Studios to depart',
#   'https://seekingalpha.com/news/3373203-head-amazon-studios-depart'],
#  ['AMZN',
#   '07/23/2018',
#   'Amazon accelerator announces new startups',
#   'https://seekingalpha.com/news/3372451-amazon-accelerator-announces-new-startups'],
#  ['AMZN',
#   '07/23/2018',
#   'Amazon -1.5% as President Trump tweets about Post Office, Washington Post',
#   'https://seekingalpha.com/news/3372371-amazon-minus-1_5-percent-president-trump-tweets-post-office-washington-post'],
#  ['AMZN',
#   '07/21/2018',
#   'Amazon, Toyota, Alcoa attempt to counter tariffs',
#   'https://seekingalpha.com/news/3372197-amazon-toyota-alcoa-attempt-counter-tariffs'],
#  ['AMZN',
#   '07/20/2018',
#   'Deutsche Bank: Amazon top internet pick with 21% upside',
#   'https://seekingalpha.com/news/3371997-deutsche-bank-amazon-top-internet-pick-21-percent-upside'],
#  ['AMZN',
#   '07/25/2018  11:13',
#   'TGV Partners Fund Shareholder Letter H1 2018',
#   'https://seekingalpha.com/article/4189881-tgv-partners-fund-shareholder-letter-h1-2018'],
#  ['AMZN',
#   '07/25/2018  10:00',
#   "How To Make Sense Of Amazon's Mad Valuation",
#   'https://seekingalpha.com/article/4189659-make-sense-amazons-mad-valuation'],
#  ['FB',
#   '07/25/2018  17:40',
#   'Facebook -20% on guidance for slowing revenue growth',
#   'https://seekingalpha.com/news/3373825-facebook-minus-20-percent-guidance-slowing-revenue-growth'],
#  ['FB',
#   '07/25/2018  17:06',
#   'Twitter, Snap dip amid Facebook earnings slide',
#   'https://seekingalpha.com/news/3373782-twitter-snap-dip-amid-facebook-earnings-slide'],
#  ['FB',
#   '07/25/2018  16:13',
#   'Facebook -8.3% as revenues trail expectations',
#   'https://seekingalpha.com/news/3373630-facebook-minus-8_3-percent-revenues-trail-expectations'],
#  ['FB',
#   '07/25/2018  16:07',
#   'Facebook beats by $0.03, misses on revenue',
#   'https://seekingalpha.com/news/3373612-facebook-beats-0_03-misses-revenue'],
#  ['FB',
#   '07/25/2018  10:17',
#   'NYT: China withdraws approval for Facebook unit',
#   'https://seekingalpha.com/news/3373474-nyt-china-withdraws-approval-facebook-unit'],
#  ['FB',
#   '07/25/2018  10:59',
#   'RV Capital Co Investor Letter H1 2018',
#   'https://seekingalpha.com/article/4189877-rv-capital-co-investor-letter-h1-2018'],
#  ['FB',
#   '07/24/2018 20:10',
#   'Facebook Q2: Instagram Vs. #DeleteFacebook',
#   'https://seekingalpha.com/article/4189683-facebook-q2-instagram-vs-deletefacebook'],
#  ['MSFT',
#   '07/20/2018',
#   'Piper Jaffray raises its Microsoft target to near $1T market cap',
#   'https://seekingalpha.com/news/3372136-piper-jaffray-raises-microsoft-target-near-1t-market-cap'],
#  ['MSFT',
#   '07/20/2018',
#   'Microsoft hits all-time high after earnings strength',
#   'https://seekingalpha.com/news/3372088-microsoft-hits-time-high-earnings-strength'],
#  ['MSFT',
#   '07/20/2018',
#   'Analysts boost Microsoft targets after strong earnings',
#   'https://seekingalpha.com/news/3372006-analysts-boost-microsoft-targets-strong-earnings'],
#  ['MSFT',
#   '07/20/2018',
#   'Microsoft +3.7% after upside Q1 guidance',
#   'https://seekingalpha.com/news/3371935-microsoft-plus-3_7-percent-upside-q1-guidance'],
#  ['MSFT',
#   '07/19/2018',
#   'Microsoft Corporation (MSFT) CEO Satya Nadella on Q4 2018 Results - Earnings Call Transcript',
#   'https://seekingalpha.com/article/4188569-microsoft-corporation-msft-ceo-satya-nadella-q4-2018-results-earnings-call-transcript'],
#  ['MSFT',
#   '07/25/2018  11:13',
#   'TGV Partners Fund Shareholder Letter H1 2018',
#   'https://seekingalpha.com/article/4189881-tgv-partners-fund-shareholder-letter-h1-2018'],
#  ['MSFT',
#   '07/24/2018 14:45',
#   'Microsoft Overvaluation Concerns: DéJà Vu All Over Again',
#   'https://seekingalpha.com/article/4189584-microsoft-overvaluation-concerns-deja-vu']]

# %%
# Wall Street Journal News Parser

stocks = ["TSLA", "GOOG", "AAPL", "AMZN", "FB", "MSFT"]

for stock in stocks :
    url = "https://quotes.wsj.com/"+stock
    req = urllib.request.Request(url, headers={'User-Agent' : "foobar"})
    sourcehtml = urlopen(req)
    soup = bs.BeautifulSoup(sourcehtml,"lxml")
    Top5 = 0

#Parse the document using soup object and extract the required text 
    mydivs = soup.findAll("span", {"class":"headline"}) 
    mydiv_time = soup.findAll("li", {"class":"cr_dateStamp"})
    
    mydiv_url = soup.findAll("span", {"class":"headline"})
    
    print("-----------"+stock+"------------")
    
    for i,div in enumerate(mydivs):
        if Top5 >=5 :
            break;
        atextHolder = div.findAll('a')
        articleHolder = atextHolder[0].get_text().strip()
        url = mydiv_url[i].find('a').attrs['href']
        #print("TIME:" , mydiv_time[i].get_text())
        #print ("HEADLINE:" ,articleHolder)
        #print("URL:" ,url)
        print(mydiv_time[i].get_text()+" -  "+articleHolder)
        print(url)
        Top5 =  Top5 + 1
# Out:
# -----------TSLA------------
# 2 min ago -  Elon Musk allegedly silences one of his short-selling critics by calling his boss
# http://www.marketwatch.com/story/elon-musk-allegedly-silences-one-of-his-short-selling-critics-by-calling-his-boss-2018-07-25
# 8 hours ago -  Tesla’s stock volatility is bewildering, says Morgan Stanley
# http://www.marketwatch.com/story/teslas-stock-volatility-is-bewildering-says-morgan-stanley-2018-07-24
# 10 hours ago -  Self-Driving and Electric Vehicles are Combining to Make the Cars of the Future
# http://www.wsj.com/articles/PR-CO-20180725-909652
# 07/24/18 -  Earnings: GM, Fiat Look Better Than Ford, Tesla
# https://www.barrons.com/articles/earnings-gm-fiat-look-better-than-ford-tesla-1532453519
# 07/24/18 -  Tesla says it did not ask suppliers for cash back
# http://www.marketwatch.com/story/tesla-says-it-did-not-ask-suppliers-for-cash-back-2018-07-23
# -----------GOOG------------
# 13 hours ago -  Dow ends 3-day losing streak as earnings lift stocks
# http://www.marketwatch.com/story/dow-looks-poised-to-break-a-losing-run-ahead-of-earnings-barrage-2018-07-24
# 07/24/18 -  Nvidia rides the next wave in artificial intelligence with Google
# http://www.marketwatch.com/story/nvidia-rides-the-next-wave-in-artificial-intelligence-with-google-2018-07-24
# 07/24/18 -  With the $1 trillion barrier in sight, this surprising tech stock is the best buy
# http://www.marketwatch.com/story/with-the-1-trillion-barrier-in-sight-this-surprising-tech-stock-is-the-best-buy-2018-07-24
# 07/24/18 -  Alphabet stock soars to record highs as Google earnings smash expectations
# http://www.marketwatch.com/story/alphabet-stock-soars-to-potential-record-highs-as-google-earnings-smash-expectations-2018-07-23
# 07/24/18 -  Should you buy stock in Dover Downs Gaming, Google, Lockheed Martin Corporation, Verizon Communications or Wells Fargo & Co.?
# http://www.wsj.com/articles/PR-CO-20180724-909173
# -----------AAPL------------
# 9 hours ago -  Thinking about buying stock in Apple, Advanced Micro Devices, Fitbit, GoPro or Netflix?
# http://www.wsj.com/articles/PR-CO-20180725-910491
# 10 hours ago -  Self-Driving and Electric Vehicles are Combining to Make the Cars of the Future
# http://www.wsj.com/articles/PR-CO-20180725-909652
# 07/24/18 -  Alphabet, Up 19% in 2018, Still Has Room to Rise
# https://www.barrons.com/articles/alphabet-up-19-in-2018-still-has-room-to-rise-1532469587
# 07/24/18 -  Why Broadcom Could Jump 66%
# https://www.barrons.com/articles/why-broadcom-stock-could-jump-66-1532448515
# 07/24/18 -  With the $1 trillion barrier in sight, this surprising tech stock is the best buy
# http://www.marketwatch.com/story/with-the-1-trillion-barrier-in-sight-this-surprising-tech-stock-is-the-best-buy-2018-07-24
# -----------AMZN------------
# 19 min ago -  AWS Makes New Amazon EC2 Instances Available to Process Large Amounts of Data, Faster
# http://www.wsj.com/articles/PR-CO-20180725-920492
# 8 hours ago -  Why you should buy shares of companies whose CEOs have skin in the game
# http://www.marketwatch.com/story/why-you-should-buy-shares-of-companies-whose-ceos-have-skin-in-the-game-2018-07-19
# 9 hours ago -  Amazon Plans New Fulfillment Center in Ontario
# http://www.wsj.com/articles/PR-CO-20180725-910653
# 9 hours ago -  Amazon Expands Footprint in Ontario with New Fulfillment Centre in Caledon
# http://www.wsj.com/articles/PR-CO-20180725-910091
# 10 hours ago -  Amazon earnings: Prime Day isn’t the only thing giving business a boost
# http://www.marketwatch.com/story/amazon-earnings-prime-day-isnt-the-only-thing-giving-business-a-boost-2018-07-23
# -----------FB------------
# 7 min ago -  U.S. Stocks Soar on Trade Concessions
# https://www.wsj.com/articles/global-stocks-pause-as-trade-tensions-weigh-1532505007
# 20 min ago -  Senate Panel Invites Three Tech Firms to Another Hearing on Russian Influence
# https://www.wsj.com/articles/senate-panel-invites-three-tech-firms-to-another-hearing-on-russian-influence-1532557373
# 24 min ago -  Facebook Is Losing the Best Kind of Friends
# https://www.wsj.com/articles/facebook-is-losing-the-best-kind-of-friends-1532557463
# 55 min ago -  Facebook Shares Tumble as Revenue Falls Short, Sales Outlook Darkens
# https://www.wsj.com/articles/facebook-revenue-falls-short-of-expectations-1532549650
# 59 min ago -  Facebook stock drops more than 20% after revenue forecast misses
# http://www.marketwatch.com/story/facebook-stock-crushed-after-revenue-user-growth-miss-2018-07-25
# -----------MSFT------------
# 07/24/18 -  With the $1 trillion barrier in sight, this surprising tech stock is the best buy
# http://www.marketwatch.com/story/with-the-1-trillion-barrier-in-sight-this-surprising-tech-stock-is-the-best-buy-2018-07-24
# 07/24/18 -  Silicon Valley to Big Oil: We Can Manage Your Data Better Than You
# https://www.wsj.com/articles/silicon-valley-courts-a-wary-oil-patch-1532424600
# 07/24/18 -  RTO Wireless and Microsoft announce agreement to deliver broadband internet to rural communities in New York and Maine
# http://www.wsj.com/articles/PR-CO-20180724-908647
# 07/24/18 -  Artificial Intelligence Growing Influence Across Number of Industries now Disrupting CyberSecurity
# http://www.wsj.com/articles/PR-CO-20180724-908178
# 07/23/18 -  Microsoft shows it deserves place among tech giants
# http://www.marketwatch.com/story/microsoft-shows-it-deserves-place-among-tech-giants-2018-07-19

# %%
# Create Soup object by passing HTML string


stocks = ["TSLA", "GOOG", "AAPL", "AMZN", "FB", "MSFT"]

for stock in stocks :
    url = "https://quotes.wsj.com/"+stock
    req = urllib.request.Request(url, headers={'User-Agent' : "foobar"})
    sourcehtml = urlopen(req)
    soup = bs.BeautifulSoup(sourcehtml,"lxml")
    Top5 = 0

#Parse the document using soup object and extract the required text 
    mydivs = soup.findAll("span", {"class":"headline"}) 
    mydiv_time = soup.findAll("li", {"class":"cr_dateStamp"})
    mydiv_url = soup.findAll("span", {"class":"headline"})
    
    print("-----------"+stock+"------------")
    
    for i,div in enumerate(mydivs):
        if Top5 >=5 :
            break;
        atextHolder = div.findAll('a')
        articleHolder = atextHolder[0].get_text().strip()
        url = mydiv_url[i].find('a').attrs['href']
        #print("TIME:" , mydiv_time[i].get_text())
        #print ("HEADLINE:" ,articleHolder)
        #print("URL:" ,url)
        dt = mydiv_time[i].get_text()
        savedate = ConvertDate(dt)        
        print(savedate+" -  "+articleHolder)
        print(url)
        Top5 =  Top5 + 1
# Out:
# -----------TSLA------------
# 07/25/2018 15:49 -  Elon Musk allegedly silences one of his short-selling critics by calling his boss
# http://www.marketwatch.com/story/elon-musk-allegedly-silences-one-of-his-short-selling-critics-by-calling-his-boss-2018-07-25
# 07/25/2018 07:17 -  Tesla’s stock volatility is bewildering, says Morgan Stanley
# http://www.marketwatch.com/story/teslas-stock-volatility-is-bewildering-says-morgan-stanley-2018-07-24
# 07/25/2018 06:17 -  Self-Driving and Electric Vehicles are Combining to Make the Cars of the Future
# http://www.wsj.com/articles/PR-CO-20180725-909652
# 07/24/18 -  Earnings: GM, Fiat Look Better Than Ford, Tesla
# https://www.barrons.com/articles/earnings-gm-fiat-look-better-than-ford-tesla-1532453519
# 07/24/18 -  Tesla says it did not ask suppliers for cash back
# http://www.marketwatch.com/story/tesla-says-it-did-not-ask-suppliers-for-cash-back-2018-07-23
# -----------GOOG------------
# 07/25/2018 16:05 -  Facebook, Google, Twitter asked to appear before Senate again to discuss Russian meddling
# http://www.marketwatch.com/story/facebook-google-twitter-asked-to-appear-before-senate-again-to-discuss-russian-meddling-2018-07-25
# 07/25/2018 02:17 -  Dow ends 3-day losing streak as earnings lift stocks
# http://www.marketwatch.com/story/dow-looks-poised-to-break-a-losing-run-ahead-of-earnings-barrage-2018-07-24
# 07/24/18 -  Nvidia rides the next wave in artificial intelligence with Google
# http://www.marketwatch.com/story/nvidia-rides-the-next-wave-in-artificial-intelligence-with-google-2018-07-24
# 07/24/18 -  With the $1 trillion barrier in sight, this surprising tech stock is the best buy
# http://www.marketwatch.com/story/with-the-1-trillion-barrier-in-sight-this-surprising-tech-stock-is-the-best-buy-2018-07-24
# 07/24/18 -  Alphabet stock soars to record highs as Google earnings smash expectations
# http://www.marketwatch.com/story/alphabet-stock-soars-to-potential-record-highs-as-google-earnings-smash-expectations-2018-07-23
# -----------AAPL------------
# 07/25/2018 07:17 -  Thinking about buying stock in Apple, Advanced Micro Devices, Fitbit, GoPro or Netflix?
# http://www.wsj.com/articles/PR-CO-20180725-910491
# 07/25/2018 06:17 -  Self-Driving and Electric Vehicles are Combining to Make the Cars of the Future
# http://www.wsj.com/articles/PR-CO-20180725-909652
# 07/24/18 -  Alphabet, Up 19% in 2018, Still Has Room to Rise
# https://www.barrons.com/articles/alphabet-up-19-in-2018-still-has-room-to-rise-1532469587
# 07/24/18 -  Why Broadcom Could Jump 66%
# https://www.barrons.com/articles/why-broadcom-stock-could-jump-66-1532448515
# 07/24/18 -  With the $1 trillion barrier in sight, this surprising tech stock is the best buy
# http://www.marketwatch.com/story/with-the-1-trillion-barrier-in-sight-this-surprising-tech-stock-is-the-best-buy-2018-07-24
# -----------AMZN------------
# 07/25/2018 15:31 -  AWS Makes New Amazon EC2 Instances Available to Process Large Amounts of Data, Faster
# http://www.wsj.com/articles/PR-CO-20180725-920492
# 07/25/2018 08:17 -  Why you should buy shares of companies whose CEOs have skin in the game
# http://www.marketwatch.com/story/why-you-should-buy-shares-of-companies-whose-ceos-have-skin-in-the-game-2018-07-19
# 07/25/2018 07:17 -  Amazon Plans New Fulfillment Center in Ontario
# http://www.wsj.com/articles/PR-CO-20180725-910653
# 07/25/2018 06:17 -  Amazon Expands Footprint in Ontario with New Fulfillment Centre in Caledon
# http://www.wsj.com/articles/PR-CO-20180725-910091
# 07/25/2018 06:17 -  Amazon earnings: Prime Day isn’t the only thing giving business a boost
# http://www.marketwatch.com/story/amazon-earnings-prime-day-isnt-the-only-thing-giving-business-a-boost-2018-07-23
# -----------FB------------
# 07/25/2018 16:05 -  Facebook, Google, Twitter asked to appear before Senate again to discuss Russian meddling
# http://www.marketwatch.com/story/facebook-google-twitter-asked-to-appear-before-senate-again-to-discuss-russian-meddling-2018-07-25
# 07/25/2018 16:00 -  U.S. Stocks Soar on Trade Concessions
# https://www.wsj.com/articles/global-stocks-pause-as-trade-tensions-weigh-1532505007
# 07/25/2018 15:52 -  Senate Panel Invites Three Tech Firms to Another Hearing on Russian Influence
# https://www.wsj.com/articles/senate-panel-invites-three-tech-firms-to-another-hearing-on-russian-influence-1532557373
# 07/25/2018 15:24 -  Facebook Is Losing the Best Kind of Friends
# https://www.wsj.com/articles/facebook-is-losing-the-best-kind-of-friends-1532557463
#  -  Facebook Shares Tumble as Revenue Falls Short, Sales Outlook Darkens
# https://www.wsj.com/articles/facebook-revenue-falls-short-of-expectations-1532549650
# -----------MSFT------------
# 07/24/18 -  With the $1 trillion barrier in sight, this surprising tech stock is the best buy
# http://www.marketwatch.com/story/with-the-1-trillion-barrier-in-sight-this-surprising-tech-stock-is-the-best-buy-2018-07-24
# 07/24/18 -  Silicon Valley to Big Oil: We Can Manage Your Data Better Than You
# https://www.wsj.com/articles/silicon-valley-courts-a-wary-oil-patch-1532424600
# 07/24/18 -  RTO Wireless and Microsoft announce agreement to deliver broadband internet to rural communities in New York and Maine
# http://www.wsj.com/articles/PR-CO-20180724-908647
# 07/24/18 -  Artificial Intelligence Growing Influence Across Number of Industries now Disrupting CyberSecurity
# http://www.wsj.com/articles/PR-CO-20180724-908178
# 07/23/18 -  Microsoft shows it deserves place among tech giants
# http://www.marketwatch.com/story/microsoft-shows-it-deserves-place-among-tech-giants-2018-07-19

# %%
from datetime import date, timedelta
from datetime import datetime
def ConvertDate(dt = "Today"):
   """Return date in mm/dd/yyyy format"""
   
   if dt.find("Today") != -1:
        #try:
          dts = dt.split(" ")
          hm = dts[1]
          m = hm.split(':')[1]
          h = hm.split(':')[0]
          ampm = dts[2]   
          print(h)
          if ampm =="PM":                         
             h = int(h) 
             if h < 12:
                h = h+12
          today2 = datetime(date.today().year, date.today().month, date.today().day, int(h), int(m), 0)
          print(today2)
          return today2.strftime('%m/%d/%Y  %H:%M')
        #except: return ''
   elif dt.find("Yesterday") != -1:
        try:
          yest = date.today() - timedelta(days=1)
          dts = dt.split(" ")
          hm = dts[1]
          m = hm.split(':')[1]
          h = hm.split(':')[0]
          ampm = dts[2]        
          if ampm =="PM":             
             h = int(h) 
             if h < 12:
                h = h+12
          yest2 = datetime(yest.year, yest.month, yest.day, int(h), int(m), 0)
          return yest2.strftime('%m/%d/%Y %H:%M')
        except: return ''
   elif dt.find(",") != -1 :
       try:
         dts = dt.split(",")
         if(len(dts)>=2):
           dtnew =  dts[1].strip()+ ' ' + str(datetime.now().year)
           #print(dtnew)
         dt_new_format = datetime.strptime(dtnew, '%b. %d %Y')
         return dt_new_format.strftime("%m/%d/%Y")
       except: return ''
   elif dt.find("hours") != -1 :
        try:
          dts = dt.split(" ")
          #print(dts[0])
          today = datetime.now() - timedelta(hours=int(dts[0]))
          return today.strftime('%m/%d/%Y %H:%M')
        except: return ''
   elif dt.find("min") != -1 :
       try:
        dts = dt.split(" ")
        today = datetime.now() - timedelta(minutes=int(dts[0]))
        return today.strftime('%m/%d/%Y %H:%M')
       except: return ''
   elif dt.find('/') != -1 :
       try:
         return dt
       except: return ''
   else:
        return ''
