# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Start with dataframe with ticker, date, title, link and text. Code for reading in file can be removed once connected to article text data directly.

# %%
df = pd.read_csv("C:\\Users\\shikh\\Desktop\\Practicum\\WSJoutput11.csv",header = None, encoding = "ISO-8859-1")
df.columns = ['Ticker','Date','Title','Link','Text']

# %%
df.head()
# Out:
#   Ticker              Date                                              Title  \
# 0   TSLA  08/07/2018 16:46  Elon Musks Tesla Claim Could Land Him in Regu...
# 1   TSLA  08/07/2018 16:41  Skepticism over Elon Musks special purpose f...
# 2   TSLA  08/07/2018 16:34  Musk Says in Tweet He Is Considering Taking Te...
# 3   TSLA  08/07/2018 16:23  Tesla short sellers walloped after Musk talks ...
# 4   TSLA               NaN  A Tesla buyout would be the largest in history...
#
#                                                 Link  \
# 0  https://www.wsj.com/articles/elon-musks-tesla-...
# 1  http://www.marketwatch.com/story/skepticism-ov...
# 2  https://www.wsj.com/articles/elon-musks-twitte...
# 3  http://www.marketwatch.com/story/tesla-short-s...
# 4  http://www.marketwatch.com/story/a-tesla-buyou...
#
#                                                 Text
# 0                                                NaN
# 1  A number of bankers and private-equity investo...
# ...

# %% [markdown]
# Set "articles" equal to column with text data.

# %%
df = df[df['Text'].isnull() == False]
df
# Out:
#    Ticker              Date  \
# 1    TSLA  08/07/2018 16:41
# 3    TSLA  08/07/2018 16:23
# 4    TSLA               NaN
# 5    TSLA  08/07/2018 15:21
# 8    TSLA  08/07/2018 14:21
# 9    TSLA  08/07/2018 14:21
# 10   GOOG  08/07/2018 13:21
# 11   GOOG  08/07/2018 09:21
# 12   GOOG          08/06/18
# 13   GOOG          08/04/18
# 14   GOOG          08/04/18
# 15   GOOG          08/03/18
# 16   GOOG          08/02/18
# 17   GOOG          08/01/18
# 18   GOOG          08/01/18
#
#                                                 Title  \
# 1   Skepticism over Elon Musks special purpose f...
# 3   Tesla short sellers walloped after Musk talks ...
# 4   A Tesla buyout would be the largest in history...
# 5   Did Elon Musk break any laws with his going-pr...
# 8   Tesla confirms intention to go private, sendin...
# 9   Elon Musk lights up the internet and investors...
# 10  Growth or value stocks? These companies may pr...
# 11  Money flows of 11 popular tech stocks show Alp...
# ...

# %%
def Sentiment(a):
    from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
    analyzer = SentimentIntensityAnalyzer()
    vs= analyzer.polarity_scores(a)
    b=analyzer.polarity_scores(a)['compound']
    if b>=0.5:
        return "Positive" 
    elif(b > -0.5 and b < 0.5):
        return "Neutral" 
    else:
        return "Negative" 
    
def Score(a):
    from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
    analyzer = SentimentIntensityAnalyzer()
    vs= analyzer.polarity_scores(a)
    b=analyzer.polarity_scores(a)['compound']
    return b

# %%
df['Sentiment']=df['Text'].apply(lambda x: Sentiment(x))
df['Score']=df['Text'].apply(lambda x: Score(x))

# %%
df.head(10)
len(df)
df.to_csv('C:\\Users\\shikh\\Desktop\\Practicum\\df.csv')

# %%
df.head(10)
# Out:
#    Ticker              Date  \
# 1    TSLA  08/07/2018 16:41
# 3    TSLA  08/07/2018 16:23
# 4    TSLA               NaN
# 5    TSLA  08/07/2018 15:21
# 8    TSLA  08/07/2018 14:21
# 9    TSLA  08/07/2018 14:21
# 10   GOOG  08/07/2018 13:21
# 11   GOOG  08/07/2018 09:21
# 12   GOOG          08/06/18
# 13   GOOG          08/04/18
#
#                                                 Title  \
# 1   Skepticism over Elon Musks special purpose f...
# 3   Tesla short sellers walloped after Musk talks ...
# 4   A Tesla buyout would be the largest in history...
# 5   Did Elon Musk break any laws with his going-pr...
# 8   Tesla confirms intention to go private, sendin...
# 9   Elon Musk lights up the internet and investors...
# 10  Growth or value stocks? These companies may pr...
# 11  Money flows of 11 popular tech stocks show Alp...
# 12  Facebook removes Infowars pages, following App...
# 13  These 10 companies have recently raised their ...
#
# ...
