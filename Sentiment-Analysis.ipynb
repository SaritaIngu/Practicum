# %%
#Reading all the files (stop words, negative and positive words into 3 different dictionaries)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import seaborn as sns
import pandas as pd
import numpy as np
# %pylab inline

import sklearn as sk
import sklearn.tree as tree
from IPython.display import Image  

import bs4 as bs
import csv
import requests
import urllib
from urllib.request import urlopen
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Sentiment Analysis

# %%
##Reading stop words into stop_words dictionary

stop_words={}
with open("C:\\Users\\shikh\\Desktop\\Practicum\\stop_words.txt",'r') as sw:    ##opening stop_words.txt file
    for line in sw:                        
        line =line.strip()               ##stripping any blank spaces from the beginning & end of line
        stop_words[line] = 0             ## Entering the word to stop_words dictionary

# %%
##Reading negative words into negative_words dictionary
negative_words={}
with open("C:\\Users\\shikh\\Desktop\\Practicum\\negative-words.txt",'r') as nw:          ##opening negative_words.txt file
    for line in nw:
        line = line.strip()                         ##stripping any blank spaces from the beginning & end of line
        negative_words[line] = 0                     ## Entering the word to negative_words dictionary

# %%
##Reading negative words into positive_words dictionary
positive_words={}
with open("C:\\Users\\shikh\\Desktop\\Practicum\\positive-words.txt",'r') as pw:   ##opening postive_words.txt file
    for line in pw:
        line = line.strip()                  ##stripping any blank spaces from the beginning & end of line
        positive_words[line] = 0             ## Entering the word to postive_words dictionary

# %%
# Check if words have been loaded or not
print(len(stop_words))                  
print(len(negative_words))
print(len(positive_words))
# Out:
# 119
# 4783
# 2007

# %%
# Read the tweet file and identify number of positive and negative words while taking care of stop words
positive_tweets=0
negative_tweets=0
##defining clean(word) function for the purpose of removing special characters
def clean(word):
    symbols = ['!','@','#','$','%','_','^','&','*','(',')','-','+','=','?']
    for symbol in symbols:
        word = word.replace(symbol,'')
    return word

with open("C:\\Users\\shikh\\Desktop\\Practicum\\Apple_India.txt",'r') as tweets:            ###opening original tweet file
    for line in tweets:                         
        line = line.strip()                       ##stripping characters before and after the line
        words = line.split()                      ## getting words from  the lines
        for word in words:
            word = word.lower()                 ##getting lower case of the word
            word = clean(word)                  ##applying clean function to the words
            print(word)
            if word not in stop_words:          ##check if word  is not in stop_words dictionary
                if word in positive_words:      ## check if the word is in positive_words dictionary 
                    print('+')
                    positive_tweets = positive_tweets +1       ###if yes add 1 to count of positive_tweets
                elif word in negative_words:                    ##if no checck if the words is in negative_words dictionary
                    negative_tweets = negative_tweets -1        ## if yes substract 1 from the count of negative_tweets
                    print('-')
                    
##concatenating string POSITIVE COUNT:with string of positive_tweets
print("POSITIVE COUNT:" + str(positive_tweets))  
##concatenating string NEGATIVE COUNT:with string of negative_tweets
print("NEGATIVE COUNT:" + str(negative_tweets))           

# Concatening and printing sum of positive and negative tweets:

print("SUM IS:" + str(positive_tweets+negative_tweets))
# Out:
# bloomberg:
# apple
# loses
# -
# key
# execs
# in
# india
# struggles
# -
# jul.
# 16,
# 2018
# 8:05
# am
# et|about:
# apple
# inc.
# aapl|by:
# brandy
# betz,
# sa
# news
# editor
# apple
# nasdaq:aapl
# has
# lost
# -
# three
# execs
# in
# india
# in
# recent
# weeks,
# according
# to
# bloomberg
# sources.
# the
# departures
# include
# the
# national
# sales
# and
# distribution
# chief,
# the
# commercial
# channels
# and
# midmarket
# business
# head,
# and
# the
# leader
# of
# telecom
# carrier
# sales.
# apple
# has
# struggled
# -
# to
# gain
# +
# traction
# +
# in
# india
# due
# to
# high
# import
# tariffs
# and
# a
# consumer
# base
# that
# prefers
# +
# cheaper
# +
# smartphones.
# apple
# has
# a
# singledigit
# market
# share
# in
# the
# country.
# sources
# say
# apple
# has
# been
# slow
# -
# to
# cultivate
# local
# business
# relationships
# and
# has
# had
# difficulties
# -
# understanding
# the
# market.
# michel
# coulomb
# took
# over
# as
# head
# of
# indian
# operations
# last
# december.
# coulomb
# has
# been
# with
# apple
# since
# 2003
# and
# was
# previously
# the
# south
# asia
# managing
# director.
# apple
# shares
# are
# up
# 0.2
# premarket
# to
# 191.65.
# previously:
# apple
# roundup:
# production
# starts
# on
# iphone
# 6s
# in
# india,
# barclays
# forecasts
# june
# q
# june
# 26
# POSITIVE COUNT:4
# NEGATIVE COUNT:-6
# SUM IS:-2

# %% [markdown]
# ##Therefore, the sum of all values observed  is -2
# ##The general sentiment is negative.
